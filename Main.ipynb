# %%
# !pip install ipynb

# %%
import torch
import gc

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 20

# %%
from ipynb.fs.full.Normalization_to_import import *
# Out:
# Execution time: 0.6159143447875977 seconds

# %%
from ipynb.fs.full.Data_Generation_to_import import *
# Out:
# Execution time: 0.034474849700927734 seconds

# %%
from ipynb.fs.full.Machine_Learning_to_import import *
# Out:
# Execution time: 310.8871395587921 seconds
# Metrics for not normalized data is ready. Run 'metrics.main()'!
# Execution time: 310.10402631759644 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'metrics_maxAbsScaler.main()'!
# Execution time: 308.42334747314453 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'metrics_MinMaxScaler.main()'!
# Execution time: 308.4925067424774 seconds
# Metrics for normalizer normalized data is ready. Run 'metrics_normalizer.main()'!
# Execution time: 310.77658009529114 seconds
# Metrics for robust_scaler normalized data is ready. Run 'metrics_robust_scaler.main()'!
# Execution time: 315.1436631679535 seconds
# Metrics for standard_scaler normalized data is ready. Run 'metrics_standard_scaler.main()'!
# Execution time: 314.2901246547699 seconds
# Metrics for binarizer normalized data is ready. Run 'metrics_binarizer.main()'!
# Execution time: 312.4534959793091 seconds
# ...

# %%
from ipynb.fs.full.MultiClass_to_import import *
# Out:
# Execution time: 0.5045187473297119 seconds
# Execution time: 0.02783370018005371 seconds
# Execution time: 4.251593112945557 seconds
# Metrics for not normalized data is ready. Run 'multiclass_metrics.main()'!
# Execution time: 1.3196077346801758 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'multiclass_maxAbsScaler_metrics.main()'!
# Execution time: 1.3383057117462158 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'multiclass_MinMaxScaler_metrics.main()'!
# Execution time: 1.3403007984161377 seconds
# Metrics for normalizer normalized data is ready. Run 'multiclass_normalizer_metrics.main()'!
# Execution time: 1.3382670879364014 seconds
# Metrics for robust_scaler normalized data is ready. Run 'multiclass_robust_scaler_metrics.main()'!
# Execution time: 1.3396823406219482 seconds
# Metrics for standard_scaler normalized data is ready. Run 'multiclass_standard_scaler_metrics.main()'!
# Execution time: 1.3350071907043457 seconds
# ...

# %%
from ipynb.fs.full.Naive_Bayes_to_import import *
# Out:
# /home/xy/Desktop/ml/rapids-cuml/lib/python3.10/site-packages/cuml/naive_bayes/naive_bayes.py:1563: UserWarning: X dtype is not int32. X will be converted, which will increase memory consumption
#   warnings.warn(
# /home/xy/Desktop/ml/rapids-cuml/lib/python3.10/site-packages/cuml/naive_bayes/naive_bayes.py:1589: UserWarning: X dtype is not int32. X will be converted, which will increase memory consumption
#   warnings.warn(
# Execution time: 0.23579621315002441 seconds
# Metrics for not normalized data is ready. Run 'metrics.main()'!
# Execution time: 0.2034013271331787 seconds
# Metrics for MaxAbsScaler normalized data is ready. Run 'metrics_MaxAbsScaler.main()'!
# Execution time: 0.2004380226135254 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'metrics_MinMaxScaler.main()'!
# Execution time: 0.21877622604370117 seconds
# Metrics for Normalizer normalized data is ready. Run 'metrics_Normalizer.main()'!
# Execution time: 0.21009302139282227 seconds
# ...

# %%
from ipynb.fs.full.Neighbours_to_import import *
# Out:
# Execution time: 6.883069753646851 seconds
# Metrics for not normalized data is ready. Run 'neighbours_metrics.main()'!
# Execution time: 9.330615997314453 seconds
# Metrics for MaxAbsScaler normalized data is ready. Run 'metrics_MaxAbsScaler.main()'!
# Execution time: 9.912214756011963 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'metrics_MinMaxScaler.main()'!
# Execution time: 10.158137083053589 seconds
# Metrics for Normalizer normalized data is ready. Run 'metrics_Normalizer.main()'!
# Execution time: 10.252345323562622 seconds
# Metrics for Binarizer normalized data is ready. Run 'metrics_Binarizer.main()'!
# Execution time: 10.310752153396606 seconds
# Metrics for FunctionTransformer normalized data is ready. Run 'metrics_FunctionTransformer.main()'!
# Execution time: 10.344509363174438 seconds
# Metrics for KBinsDiscretizer normalized data is ready. Run 'metrics_KBinsDiscretizer.main()'!

# %%
#ml.LogisticRegression()

# %%
#logr_predict_global_1

# %%
#nb.GaussianNB()

# %%
#bnb_predict_global_1

# %%
#gnb_predict_global_1['HeartDiseaseorAttack'].unique()

# %%
#knc_predict_global_1

# %%
#knc_predict_global_1['HeartDiseaseorAttack'].unique()

# %%
#neighbours_metrics.main()

# %%
#knr_predict_global_1['HeartDiseaseorAttack'].unique()

# %%
#multiclass_function_transformer_metrics.main()

# %%
#ovoc_predict_global_1
