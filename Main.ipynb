# %%
# !pip install ipynb
# Out:
# Requirement already satisfied: ipynb in ./rapids-cuml/lib/python3.10/site-packages (0.5.1)

# %%
import torch
import gc

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 20

# %%
from ipynb.fs.full.Normalization_to_import import *
# Out:
# Execution time: 0.6337800025939941 seconds

# %%
from ipynb.fs.full.Data_Generation_to_import import *
# Out:
# Execution time: 0.03440546989440918 seconds

# %%
from ipynb.fs.full.Machine_Learning_to_import import *
# Out:
# Execution time: 0.9533569812774658 seconds
# Metrics for not normalized data is ready. Run 'metrics_machine_learning.main()'!
# Execution time: 0.6031174659729004 seconds
# Metrics for maxAbsScaler normalized data is ready. Run 'metrics_maxAbsScaler_machine_learning.main()'!
# Execution time: 0.6012725830078125 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'metrics_MinMaxScaler_machine_learning.main()'!
# Execution time: 0.5982089042663574 seconds
# Metrics for normalizer normalized data is ready. Run 'metrics_normalizer_machine_learning.main()'!
# Execution time: 0.592188835144043 seconds
# Metrics for robust_scaler normalized data is ready. Run 'metrics_robust_scaler_machine_learning.main()'!
# Execution time: 0.5904266834259033 seconds
# Metrics for standard_scaler normalized data is ready. Run 'metrics_standard_scaler_machine_learning.main()'!
# Execution time: 0.58856201171875 seconds
# Metrics for binarizer normalized data is ready. Run 'metrics_binarizer_machine_learning.main()'!
# Execution time: 0.6095864772796631 seconds
# Metrics for function_transformer normalized data is ready. Run 'metrics_function_transformer_machine_learning.main()'!
# Execution time: 0.586754560470581 seconds
# Metrics for KBinsDiscretizer normalized data is ready. Run 'metrics_KBinsDiscretizer_machine_learning.main()'!

# %%
from ipynb.fs.full.Naive_Bayes_to_import import *
# Out:
# /home/xy/Desktop/ml/rapids-cuml/lib/python3.10/site-packages/cuml/naive_bayes/naive_bayes.py:1563: UserWarning: X dtype is not int32. X will be converted, which will increase memory consumption
#   warnings.warn(
# /home/xy/Desktop/ml/rapids-cuml/lib/python3.10/site-packages/cuml/naive_bayes/naive_bayes.py:1589: UserWarning: X dtype is not int32. X will be converted, which will increase memory consumption
#   warnings.warn(
# Execution time: 0.20931744575500488 seconds
# Metrics for not normalized data is ready. Run 'metrics_naive_bayes.main()'!
# Execution time: 0.19302940368652344 seconds
# Metrics for MaxAbsScaler normalized data is ready. Run 'metrics_MaxAbsScaler_naive_bayes.main()'!
# Execution time: 0.1939713954925537 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'metrics_MinMaxScaler_naive_bayes.main()'!
# Execution time: 0.20161819458007812 seconds
# Metrics for Normalizer normalized data is ready. Run 'metrics_Normalizer_naive_bayes.main()'!
# Execution time: 0.1916213035583496 seconds
# Metrics for Binarizer normalized data is ready. Run 'metrics_Binarizer_naive_bayes.main()'!
# Execution time: 0.20316457748413086 seconds
# Metrics for FunctionTransformer normalized data is ready. Run 'metrics_FunctionTransformer_naive_bayes.main()'!
# Execution time: 0.20398521423339844 seconds
# Metrics for KBinsDiscretizer normalized data is ready. Run 'metrics_KBinsDiscretizer_naive_bayes.main()'!

# %%
from ipynb.fs.full.Neighbours_to_import import *
# Out:
# Execution time: 5.561483860015869 seconds
# Metrics for not normalized data is ready. Run 'neighbours_metrics.main()'!
# Execution time: 8.287059307098389 seconds
# Metrics for MaxAbsScaler normalized data is ready. Run 'metrics_MaxAbsScaler_neighbours.main()'!
# Execution time: 9.416295051574707 seconds
# Metrics for MinMaxScaler normalized data is ready. Run 'metrics_MinMaxScaler_neighbours.main()'!
# Execution time: 9.924997806549072 seconds
# Metrics for Normalizer normalized data is ready. Run 'metrics_Normalizer_neighbours.main()'!
# Execution time: 10.302371978759766 seconds
# Metrics for Binarizer normalized data is ready. Run 'metrics_Binarizer_neighbours.main()'!
# Execution time: 10.36401629447937 seconds
# Metrics for FunctionTransformer normalized data is ready. Run 'metrics_FunctionTransformer_neighbours.main()'!
# Execution time: 10.427276372909546 seconds
# Metrics for KBinsDiscretizer normalized data is ready. Run 'metrics_KBinsDiscretizer_neighbours.main()'!

# %%
#ml.LogisticRegression()

# %%
#logr_predict_global_1

# %%
#nb.GaussianNB()

# %%
#bnb_predict_global_1

# %%
#gnb_predict_global_1['HeartDiseaseorAttack'].unique()

# %%
#knc_predict_global_1

# %%
#knc_predict_global_1['HeartDiseaseorAttack'].unique()

# %%
#neighbours_metrics.main()

# %%
#knr_predict_global_1['HeartDiseaseorAttack'].unique()

# %%
#multiclass_function_transformer_metrics.main()

# %%
#ovoc_predict_global_1
